# %% [markdown]
# # 1. Introduction
#
# Why do we need Generators? There are mainly two reasons:
#
#     - Firstly, the codes look nicer
#     - Secondly and more importantly, the performance is much better than simply using the iterator, espeically when you have a lot if items
#
# This jupter

# %%
import numpy as np
import time

# %%
def square_numbers(nums):
    result = []
    for i in nums:
        result.append(i**2)
    return result

# %%
my_nums = square_numbers([2,3,4,5])
my_nums
# Out:
# [4, 9, 16, 25]

# %% [markdown]
# However, we could also use the **yield** to create a generator like the following:

# %%
def square_numbers(nums):
    for i in nums:
        yield i**2

# %%
my_nums = square_numbers([2,3,4,5])
# print(next(my_nums))
# print(next(my_nums))
# print(next(my_nums))
# print(next(my_nums))

# %%
for num in my_nums:
    print(num)
# Out:
# 4
# 9
# 16
# 25

# %% [markdown]
# The code is much simpler than the previous function

# %% [markdown]
# # 2. Different ways of creating a generator

# %%
my_nums = [x*x for x in [1,2,3,4,5]]

print(my_nums)

for num in my_nums:
    print(num)
# Out:
# [1, 4, 9, 16, 25]
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# However, we could also construct a generator like the following:
#
# We could notice that when implementing the function:
#
# ```Python
# print(my_nums)
# ```
# a generator object is created!

# %%
my_nums = (x*x for x in [1,2,3,4,5])

print(my_nums)

for num in my_nums:
    print(num)
    
# Once you have use the print(num) statement here, the following my_nums_list would be []
# Out:
# <generator object <genexpr> at 0x000001DE1A236A40>
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# We could convert the generator object to a list by simply calling a list function:

# %%
my_nums = (x*x for x in [1,2,3,4,5])

my_nums_list = list(my_nums)
my_nums_list
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# Fianlly we give an example about how generator improves performance

# %%
a = np.random.rand(1000000, 1)

# %%
def square_numbers(nums):
    result = []
    for i in nums:
        result.append(i**2)
    return result

# %%
time1 = time.clock()
result_nums = square_numbers(a)
time2 = time.clock()
print('Total time cost: ', time2-time1)
# Out:
# Total time cost:  1.3185868611245155

# %%
result_nums
# Out:
# [array([0.18142827]),
#  array([0.09653164]),
#  array([0.32273337]),
#  array([0.36241892]),
#  array([0.01293177]),
#  array([0.13066097]),
#  array([0.0518875]),
#  array([0.30394557]),
#  array([0.66149774]),
#  array([0.01788371]),
#  array([0.35308992]),
#  array([0.00325107]),
#  array([0.00104364]),
#  array([0.14690931]),
#  array([0.4581079]),
#  array([7.12473875e-06]),
#  array([0.16137738]),
#  array([0.16823029]),
#  array([0.10793038]),
#  array([0.15326702]),
#  array([0.3185399]),
#  array([0.35441051]),
#  array([0.40621567]),
#  array([0.09662235]),
#  array([0.19859532]),
#  array([0.02059418]),
#  array([0.00786044]),
#  array([0.12508128]),
#  array([0.33196269]),
#  array([0.31195284]),
#  array([0.11972702]),
#  array([0.33060366]),
#  array([0.60658883]),
#  array([0.45786105]),
#  array([0.62090862]),
#  array([0.14009548]),
#  array([6.50419628e-05]),
#  array([0.01405655]),
#  array([0.03716944]),
#  array([0.00152242]),
#  array([0.69048947]),
#  array([0.73578714]),
#  array([0.24267621]),
#  array([0.6059607]),
#  array([0.77270799]),
#  array([0.91588237]),
#  array([0.37487811]),
#  array([0.34824214]),
#  array([0.02125174]),
#  array([0.82446327]),
#  array([0.42873438]),
#  array([0.04781228]),
#  array([0.35426613]),
#  array([0.65732846]),
#  array([0.60736175]),
#  array([0.99578552]),
#  array([0.77372145]),
#  array([0.3616249]),
#  array([0.8715956]),
#  array([0.2817405]),
#  array([0.09504281]),
#  array([1.49051893e-05]),
#  array([0.99020531]),
#  array([0.50189719]),
#  array([0.58734078]),
#  array([0.06452771]),
#  array([0.2110823]),
#  array([0.38933148]),
#  array([0.44064294]),
#  array([0.2563854]),
#  array([0.00155164]),
#  array([0.14817898]),
#  array([0.01551297]),
#  array([0.77436434]),
#  array([0.40114299]),
#  array([0.58600977]),
#  array([0.57512341]),
#  array([0.54484587]),
#  array([0.51128556]),
#  array([0.54836385]),
#  array([0.73404506]),
#  array([0.71183941]),
#  array([0.40909174]),
#  array([0.0247064]),
#  array([0.31329259]),
#  array([0.02051731]),
#  array([0.09269699]),
#  array([0.36135171]),
#  array([0.01108202]),
#  array([0.34418758]),
#  array([0.15442918]),
#  array([0.55765764]),
#  array([0.66902801]),
#  array([0.03585253]),
#  array([0.21070379]),
#  array([0.88572778]),
#  array([0.74743323]),
#  array([0.35766984]),
#  array([0.04879508]),
#  array([0.17204117]),
#  array([0.38840117]),
#  array([0.91303409]),
#  array([0.53223222]),
#  array([0.72737931]),
#  array([0.87841576]),
#  array([0.03024127]),
#  array([0.18085243]),
#  array([0.31615328]),
#  array([0.76437788]),
#  array([0.41860635]),
#  array([0.97739362]),
#  array([0.32571221]),
#  array([0.44547414]),
#  array([0.00010289]),
#  array([0.2687372]),
#  array([0.12475859]),
#  array([0.07164849]),
#  array([0.21790781]),
#  array([0.82190562]),
#  array([0.02390441]),
#  array([0.24196173]),
#  array([0.63258778]),
#  array([0.76763279]),
#  array([0.33112217]),
#  array([0.14241315]),
#  array([0.96292573]),
#  array([0.70632676]),
#  array([0.01006684]),
#  array([0.4077968]),
#  array([0.18719981]),
#  array([0.66773271]),
#  array([0.19338525]),
#  array([0.03128325]),
#  array([0.48150923]),
#  array([0.02730155]),
#  array([0.00801192]),
#  array([0.36373338]),
#  array([0.15616725]),
#  array([0.0008548]),
#  array([0.01899103]),
#  array([0.13386534]),
#  array([0.13539794]),
#  array([0.66124652]),
#  array([0.90539527]),
#  array([0.03054461]),
#  array([0.00633794]),
#  array([0.24153465]),
#  array([0.64593755]),
#  array([0.05741335]),
#  array([0.07045565]),
#  array([0.19810163]),
#  array([0.18100258]),
#  array([0.32606594]),
#  array([0.17655141]),
#  array([0.7939886]),
#  array([0.90761272]),
#  array([0.67106252]),
#  array([0.01748866]),
#  array([0.19166673]),
#  array([0.15388265]),
#  array([0.82777688]),
#  array([0.79667035]),
#  array([0.03830175]),
#  array([0.33287886]),
#  array([0.5806855]),
#  array([0.26234111]),
#  array([0.04444511]),
#  array([0.11125226]),
#  array([0.02921899]),
#  array([0.22322526]),
#  array([0.02516154]),
#  array([0.3063718]),
#  array([0.05008239]),
#  array([0.02440948]),
#  array([0.01938504]),
#  array([0.98638141]),
#  array([0.03799066]),
#  array([0.12391159]),
#  array([0.00148275]),
#  array([5.47604212e-06]),
#  array([0.31581324]),
#  array([0.45373271]),
#  array([0.73843716]),
#  array([0.83677856]),
#  array([0.00122847]),
#  array([0.23734975]),
#  array([0.00403262]),
#  array([0.58445965]),
#  array([0.00044203]),
#  array([0.57028984]),
#  array([0.61457653]),
#  array([0.48038991]),
#  array([0.7008497]),
#  array([0.08817814]),
#  array([0.13201429]),
#  array([0.65122935]),
#  array([0.01175224]),
#  array([0.0603795]),
#  array([0.29969062]),
#  array([4.13988166e-06]),
#  array([0.22465978]),
#  array([0.65125076]),
#  array([0.51161619]),
#  array([0.12815266]),
#  array([0.00492735]),
#  array([0.72190584]),
#  array([0.08321622]),
#  array([0.36971748]),
#  array([0.02670009]),
#  array([0.0768784]),
#  array([0.12407595]),
#  array([0.63993208]),
#  array([0.06442447]),
#  array([0.14585395]),
#  array([0.81340614]),
#  array([0.03002538]),
#  array([0.56288354]),
#  array([0.12730892]),
#  array([0.066758]),
#  array([0.66345949]),
#  array([0.12993282]),
#  array([0.07649055]),
#  array([0.57633431]),
#  array([0.90257514]),
#  array([0.78105018]),
#  array([0.8422299]),
#  array([0.02669026]),
#  array([0.6826753]),
#  array([0.42072794]),
#  array([0.31170683]),
#  array([0.65464802]),
#  array([0.92902279]),
#  array([0.11089251]),
#  array([0.78476814]),
#  array([0.16162347]),
#  array([0.00071561]),
#  array([0.31585903]),
#  array([0.1917702]),
#  array([0.62373153]),
#  array([0.73444295]),
#  array([0.0078804]),
#  array([0.06194445]),
#  array([0.09020594]),
#  array([0.3693247]),
#  array([0.01707475]),
#  array([0.94797524]),
#  array([0.26349463]),
#  array([0.0689733]),
#  array([0.78522063]),
#  array([0.17111351]),
#  array([0.56314486]),
#  array([0.35019196]),
#  array([0.22402534]),
#  array([0.57521634]),
#  array([0.43692655]),
#  array([0.928547]),
#  array([0.34080532]),
#  array([0.29119137]),
#  array([0.03510042]),
#  array([0.29590211]),
#  array([0.35901762]),
#  array([0.35465252]),
#  array([0.3480901]),
#  array([0.00519904]),
#  array([0.00653623]),
#  array([0.2558148]),
#  array([0.04771133]),
#  array([0.35123776]),
#  array([0.48135907]),
#  array([0.08436138]),
#  array([0.83489833]),
#  array([0.8961067]),
#  array([0.15908292]),
#  array([0.18646281]),
#  array([0.55891442]),
#  array([0.10854561]),
#  array([0.61425341]),
#  array([0.73624679]),
#  array([0.14160526]),
#  array([0.55585085]),
#  array([0.68832527]),
#  array([0.17629145]),
#  array([0.31395224]),
#  array([0.00023456]),
#  array([0.14541477]),
#  array([0.36473658]),
#  array([0.07167591]),
#  array([0.00023176]),
#  array([0.72124349]),
#  array([0.8797697]),
#  array([0.00188198]),
#  array([0.85056885]),
#  array([0.06912705]),
#  array([0.00553234]),
#  array([0.15351441]),
#  array([0.23936878]),
#  array([0.02551301]),
#  array([0.74103038]),
#  array([0.65441975]),
#  array([0.73025529]),
#  array([0.17801753]),
#  array([0.71240861]),
#  array([0.01360654]),
#  array([0.00844645]),
#  array([0.14158063]),
#  array([0.43724213]),
#  array([0.83259122]),
#  array([0.19122412]),
#  array([0.11429066]),
#  array([0.02883467]),
#  array([0.85660497]),
#  array([0.00851944]),
#  array([0.01369407]),
#  array([0.09194461]),
#  array([0.00914774]),
#  array([0.54430977]),
#  array([0.09772936]),
#  array([0.96244893]),
#  array([0.2315286]),
#  array([0.75507917]),
#  array([0.95805336]),
#  array([0.26705564]),
#  array([0.47774239]),
#  array([0.04389585]),
#  array([0.32395063]),
#  array([0.00279111]),
#  array([0.08927699]),
#  array([0.10175792]),
#  array([0.50307738]),
#  array([0.21780069]),
#  array([0.5018304]),
#  array([0.57229615]),
#  array([0.03413069]),
#  array([0.62429672]),
#  array([0.7959484]),
#  array([0.13424431]),
#  array([0.85890055]),
#  array([0.85738504]),
#  array([0.56703214]),
#  array([0.0228608]),
#  array([0.04848143]),
#  array([0.89926454]),
#  array([0.98514229]),
#  array([0.43831164]),
#  array([0.23827138]),
#  array([0.07671796]),
#  array([0.87153312]),
#  array([0.89340823]),
#  array([0.0631544]),
#  array([0.0402605]),
#  array([0.29959569]),
#  array([0.06860846]),
#  array([0.00689925]),
#  array([0.28126071]),
#  array([0.59856904]),
#  array([0.33944452]),
#  array([0.21584652]),
#  array([0.12955815]),
#  array([0.03549851]),
#  array([0.15810273]),
#  array([0.31071997]),
#  array([0.08968184]),
#  array([0.41207702]),
#  array([0.32807329]),
#  array([0.37802884]),
#  array([0.10019743]),
#  array([0.00964026]),
#  array([0.06519599]),
#  array([0.60487537]),
#  array([0.94854312]),
#  array([0.33025797]),
#  array([0.65151473]),
#  array([0.13737519]),
#  array([0.526569]),
#  array([0.22561841]),
#  array([0.95028138]),
#  array([0.03493862]),
#  array([0.23684142]),
#  array([0.49900894]),
#  array([0.71819432]),
#  array([0.12601875]),
#  array([0.3931607]),
#  array([0.01448805]),
#  array([0.38368351]),
#  array([0.41903109]),
#  array([0.88894893]),
#  array([0.00683302]),
#  array([0.54813845]),
#  array([0.09313604]),
#  array([0.10593009]),
#  array([0.42013325]),
#  array([0.14633617]),
#  array([0.41608042]),
#  array([0.84474812]),
#  array([0.03434469]),
#  array([0.02704486]),
#  array([0.01391913]),
#  array([0.60193622]),
#  array([0.03516213]),
#  array([0.27621559]),
#  array([0.31647061]),
#  array([0.08841116]),
#  array([0.73800212]),
#  array([0.19166249]),
#  array([0.19142169]),
#  array([0.1055364]),
#  array([0.00371246]),
#  array([0.82832938]),
#  array([0.05900825]),
#  array([0.02377929]),
#  array([0.29627454]),
#  array([0.78107485]),
#  array([0.13486779]),
#  array([0.17206667]),
#  array([0.74008844]),
#  array([0.57596922]),
#  array([0.19290652]),
#  array([0.41751678]),
#  array([0.85125615]),
#  array([0.04524672]),
#  array([0.5401688]),
#  array([0.71358639]),
#  array([0.27583947]),
#  array([0.08087677]),
#  array([0.422445]),
#  array([0.83905142]),
#  array([0.33542948]),
#  array([0.45442191]),
#  array([0.41120768]),
#  array([0.03092158]),
#  array([0.00487401]),
#  array([0.97527752]),
#  array([0.07454843]),
#  array([0.06708367]),
#  array([0.03664278]),
#  array([0.19146552]),
#  array([0.40808697]),
#  array([0.11045462]),
#  array([0.63072258]),
#  array([0.06021041]),
#  array([0.33838334]),
#  array([0.19217984]),
#  array([0.03951071]),
#  array([0.49646079]),
#  array([0.01134576]),
#  array([0.00666075]),
#  array([0.10744461]),
#  array([0.08174994]),
#  array([0.01909776]),
#  array([0.25214373]),
#  array([0.27802978]),
#  array([0.46716391]),
#  array([0.01421587]),
#  array([0.7051041]),
#  array([0.269563]),
#  array([0.17346752]),
#  array([0.21848249]),
#  array([0.36446307]),
#  array([0.00832895]),
#  array([0.20679768]),
#  array([0.02810351]),
#  array([0.31889793]),
#  array([0.24804205]),
#  array([0.77586613]),
#  array([0.17848852]),
#  array([0.00954316]),
#  array([0.03879964]),
#  array([0.47233651]),
#  array([0.05882892]),
#  array([7.13380827e-05]),
#  array([0.87061255]),
#  array([0.42036953]),
#  array([0.80169762]),
#  array([0.00772084]),
#  array([0.35589065]),
#  array([0.47615463]),
#  array([0.00580084]),
#  array([0.04718718]),
#  array([0.34869165]),
#  array([0.61945447]),
#  array([0.77907828]),
#  array([0.04381214]),
#  array([0.35992788]),
#  array([0.13618181]),
#  array([0.00627632]),
#  array([0.37948963]),
#  array([0.00657096]),
#  array([0.00285892]),
#  array([0.03167011]),
#  array([0.28756612]),
#  array([0.11847512]),
#  array([0.63957444]),
#  array([0.30037956]),
#  array([0.50210862]),
#  array([0.47913005]),
#  array([0.14831035]),
#  array([0.72691936]),
#  array([0.48764858]),
#  array([0.07474509]),
#  array([0.47142692]),
#  array([0.21823467]),
#  array([0.00020619]),
#  array([0.62308737]),
#  array([0.01772563]),
#  array([0.7914969]),
#  array([0.51526044]),
#  array([0.49547666]),
#  array([0.06534859]),
#  array([0.01593013]),
#  array([0.49608522]),
#  array([0.41667566]),
#  array([0.13376819]),
#  array([0.20471201]),
#  array([0.18846959]),
#  array([0.57772351]),
#  array([0.23476473]),
#  array([0.35119336]),
#  array([0.54567221]),
#  array([0.00710751]),
#  array([0.09873459]),
#  array([0.07189224]),
#  array([0.18057272]),
#  array([0.0577095]),
#  array([0.34816256]),
#  array([0.06603739]),
#  array([0.37831787]),
#  array([0.08803716]),
#  array([0.1013698]),
#  array([0.19990927]),
#  array([0.64439006]),
#  array([0.02445633]),
#  array([0.1818198]),
#  array([0.09889427]),
#  array([0.25843853]),
#  array([0.92775865]),
#  array([0.11786682]),
#  array([0.01396375]),
#  array([0.12383525]),
#  array([0.77291515]),
#  array([0.28374798]),
#  array([0.01863444]),
#  array([0.64682732]),
#  array([0.27975322]),
#  array([0.08980105]),
#  array([0.48810213]),
#  array([0.67882916]),
#  array([0.44536614]),
#  array([0.00944886]),
#  array([0.75865319]),
#  array([0.27739332]),
#  array([0.0022791]),
#  array([0.82845765]),
#  array([0.38234275]),
#  array([0.76642459]),
#  array([0.64022871]),
#  array([0.00649561]),
#  array([0.20629021]),
#  array([0.81585902]),
#  array([0.00011265]),
#  array([0.21105119]),
#  array([0.00050366]),
#  array([0.35400492]),
#  array([0.00049215]),
#  array([0.19601247]),
#  array([0.08395311]),
#  array([0.48329887]),
#  array([0.00354839]),
#  array([0.24653702]),
#  array([0.2361686]),
#  array([0.04835066]),
#  array([0.25742923]),
#  array([0.84902238]),
#  array([0.00077648]),
#  array([0.2227898]),
#  array([0.74846495]),
#  array([0.08925151]),
#  array([0.49598269]),
#  array([0.75610558]),
#  array([0.88748934]),
#  array([0.51679603]),
#  array([0.96037562]),
#  array([0.21957495]),
#  array([0.09462892]),
#  array([0.67300457]),
#  array([0.8172374]),
#  array([0.24526495]),
#  array([0.24626586]),
#  array([0.47569402]),
#  array([0.49610468]),
#  array([0.46885216]),
#  array([0.78559852]),
#  array([0.00732354]),
#  array([6.90382691e-07]),
#  array([0.26357523]),
#  array([0.10459276]),
#  array([0.4989057]),
#  array([0.00961069]),
#  array([0.52822818]),
#  array([0.24280156]),
#  array([0.97013351]),
#  array([0.89998652]),
#  array([0.00555547]),
#  array([0.65855616]),
#  array([0.35334393]),
#  array([0.37060088]),
#  array([0.02438296]),
#  array([0.16213445]),
#  array([0.19782212]),
#  array([0.00017378]),
#  array([0.21651254]),
#  array([0.05418381]),
#  array([0.02014496]),
#  array([0.05177838]),
#  array([0.6469702]),
#  array([0.89746964]),
#  array([0.11343636]),
#  array([0.02588215]),
#  array([0.10998564]),
#  array([0.66123026]),
#  array([0.46209529]),
#  array([0.15523898]),
#  array([0.37384088]),
#  array([0.46507544]),
#  array([0.53890724]),
#  array([0.44168746]),
#  array([0.63324407]),
#  array([0.83153267]),
#  array([0.00360557]),
#  array([0.00075142]),
#  array([0.0121342]),
#  array([0.45745272]),
#  array([0.00248039]),
#  array([0.99366031]),
#  array([0.68215001]),
#  array([0.00370737]),
#  array([0.00202664]),
#  array([0.02092277]),
#  array([0.89710105]),
#  array([0.00082068]),
#  array([0.8739257]),
#  array([0.2835065]),
#  array([0.39387641]),
#  array([0.26620482]),
#  array([0.22625452]),
#  array([0.15378038]),
#  array([0.52733486]),
#  array([0.14871827]),
#  array([0.09889768]),
#  array([0.90407752]),
#  array([0.01251704]),
#  array([0.36542216]),
#  array([0.1841735]),
#  array([0.00580696]),
#  array([0.03968905]),
#  array([0.65343341]),
#  array([0.02996912]),
#  array([0.127357]),
#  array([0.01880475]),
#  array([0.2325515]),
#  array([0.58055068]),
#  array([0.16040878]),
#  array([0.04300868]),
#  array([0.15262012]),
#  array([0.07091236]),
#  array([0.00010347]),
#  array([0.03842512]),
#  array([0.02897305]),
#  array([0.02388882]),
#  array([0.35483701]),
#  array([0.0361645]),
#  array([0.48101068]),
#  array([0.04437918]),
#  array([0.14302286]),
#  array([0.51953764]),
#  array([0.0890595]),
#  array([0.03536235]),
#  array([0.1541194]),
#  array([0.00069282]),
#  array([0.26130219]),
#  array([0.07701592]),
#  array([0.70419699]),
#  array([0.36190586]),
#  array([0.04013529]),
#  array([0.01078348]),
#  array([0.39901449]),
#  array([0.41748597]),
#  array([3.99908777e-05]),
#  array([0.7345277]),
#  array([0.14654358]),
#  array([0.71789253]),
#  array([0.00127956]),
#  array([0.01290468]),
#  array([0.94143398]),
#  array([0.84439102]),
#  array([0.02156027]),
#  array([0.64322127]),
#  array([0.93638993]),
#  array([0.05244719]),
#  array([0.99035456]),
#  array([0.83385891]),
#  array([0.05949067]),
#  array([0.1735517]),
#  array([0.99245341]),
#  array([0.46481002]),
#  array([0.05749429]),
#  array([0.41657838]),
#  array([0.76084593]),
#  array([0.07148964]),
#  array([0.61089408]),
#  array([0.38027349]),
#  array([0.01159897]),
#  array([0.0331319]),
#  array([0.06383484]),
#  array([0.82595251]),
#  array([0.0022091]),
#  array([0.57118084]),
#  array([0.11063947]),
#  array([0.35974174]),
#  array([0.74051171]),
#  array([0.38784662]),
#  array([0.54781308]),
#  array([0.18496613]),
#  array([0.60740509]),
#  array([0.33286126]),
#  array([0.14497087]),
#  array([0.14663805]),
#  array([0.1403872]),
#  array([0.50408278]),
#  array([0.63293267]),
#  array([0.26624285]),
#  array([0.68947044]),
#  array([0.79584103]),
#  array([0.03718671]),
#  array([0.33502966]),
#  array([0.07574934]),
#  array([0.77321292]),
#  array([0.68862036]),
#  array([0.02140667]),
#  array([0.71285866]),
#  array([0.2155092]),
#  array([0.54687809]),
#  array([0.07012792]),
#  array([0.63008381]),
#  array([0.86490824]),
#  array([0.08298941]),
#  array([9.93366503e-06]),
#  array([0.22533706]),
#  array([0.81915314]),
#  array([0.78052505]),
#  array([0.33936153]),
#  array([0.88486475]),
#  array([0.44896483]),
#  array([0.00039331]),
#  array([0.00318573]),
#  array([0.28492936]),
#  array([0.01130185]),
#  array([0.19002515]),
#  array([0.03706984]),
#  array([0.87444681]),
#  array([0.51341842]),
#  array([0.18396287]),
#  array([0.34601908]),
#  array([0.14824317]),
#  array([2.37486794e-05]),
#  array([0.30380736]),
#  array([6.85902792e-05]),
#  array([0.41838142]),
#  array([0.61869943]),
#  array([0.05870483]),
#  array([0.00199303]),
#  array([0.09393317]),
#  array([0.08697808]),
#  array([0.00403707]),
#  array([0.32348203]),
#  array([0.02298184]),
#  array([0.22837102]),
#  array([0.00144742]),
#  array([0.17981532]),
#  array([0.48172978]),
#  array([0.01186985]),
#  array([0.53769598]),
#  array([0.69359985]),
#  array([0.63895088]),
#  array([0.44185192]),
#  array([0.7132289]),
#  array([0.05949261]),
#  array([0.27753431]),
#  array([0.84094992]),
#  array([0.22188424]),
#  array([0.01207878]),
#  array([9.14358589e-05]),
#  array([0.11656825]),
#  array([0.01616631]),
#  array([0.0057055]),
#  array([0.67718918]),
#  array([0.66984463]),
#  array([0.30978341]),
#  array([0.03828895]),
#  array([0.5027667]),
#  array([0.39918721]),
#  array([0.19972838]),
#  array([0.36539283]),
#  array([0.15841624]),
#  array([0.1718368]),
#  array([0.74370895]),
#  array([0.85315505]),
#  array([0.25461494]),
#  array([0.04448547]),
#  array([0.01690894]),
#  array([0.47000631]),
#  array([0.48625681]),
#  array([0.04354872]),
#  array([0.01668169]),
#  array([0.57720935]),
#  array([0.87502701]),
#  array([0.08564537]),
#  array([0.2017649]),
#  array([0.72596093]),
#  array([0.03855062]),
#  array([0.07027322]),
#  array([0.01707488]),
#  array([0.01489947]),
#  array([0.41273483]),
#  array([0.45676884]),
#  array([0.17310717]),
#  array([0.30539577]),
#  array([0.36443554]),
#  array([0.84898632]),
#  array([0.48664738]),
#  array([0.66004442]),
#  array([0.27850203]),
#  array([0.22759273]),
#  array([0.74044231]),
#  array([0.93154779]),
#  array([0.06688525]),
#  array([0.55674161]),
#  array([0.52047371]),
#  array([0.00346059]),
#  array([2.21789876e-06]),
#  array([0.2033406]),
#  array([0.3674265]),
#  array([0.17869894]),
#  array([0.10918466]),
#  array([0.00015852]),
#  array([0.96784127]),
#  array([0.1070615]),
#  array([0.0621371]),
#  array([0.1133427]),
#  array([0.00011849]),
#  array([0.01529464]),
#  array([0.69707879]),
#  array([0.01268783]),
#  array([0.72559431]),
#  array([0.06068516]),
#  array([0.87075817]),
#  array([0.36642121]),
#  array([0.51434113]),
#  array([0.01485205]),
#  array([0.07483441]),
#  array([0.02201808]),
#  array([0.22132968]),
#  array([0.33164284]),
#  array([0.00678083]),
#  array([0.1051351]),
#  array([0.23737693]),
#  array([0.98941076]),
#  array([0.44747866]),
#  array([0.17737418]),
#  array([0.65489901]),
#  array([8.35040619e-05]),
#  array([0.00090873]),
#  array([0.30199399]),
#  array([0.14471188]),
#  array([0.75052589]),
#  array([0.74340307]),
#  array([0.06138861]),
#  array([0.00131435]),
#  array([0.01256535]),
#  array([0.45302184]),
#  array([0.47540525]),
#  array([0.13837459]),
#  array([0.64072372]),
#  array([0.04603334]),
#  array([0.22144694]),
#  array([0.00090428]),
#  array([0.25052469]),
#  array([0.06074069]),
#  array([0.04598507]),
#  array([0.02184631]),
#  array([0.88765982]),
#  array([0.93679045]),
#  array([0.30328755]),
#  array([0.44520516]),
#  array([0.97022095]),
#  array([0.43568523]),
#  array([0.36434699]),
#  array([0.17775217]),
#  array([0.04466066]),
#  array([0.38997755]),
#  array([0.10729233]),
#  array([0.95795452]),
#  array([0.09391339]),
#  array([0.12134104]),
#  array([0.05128171]),
#  array([0.68750031]),
#  array([0.77036346]),
#  array([0.94870276]),
#  array([0.94118985]),
#  array([0.17026774]),
#  array([0.48499439]),
#  array([0.86513361]),
#  array([0.54445315]),
#  array([0.01095953]),
#  array([0.5488399]),
#  array([0.0270165]),
#  array([0.02255261]),
#  array([0.70937656]),
#  array([0.50479326]),
#  array([0.96354315]),
#  array([0.14117484]),
#  array([0.85403023]),
#  array([0.01735425]),
#  array([0.40187583]),
#  array([0.99274087]),
#  array([0.10322403]),
#  array([0.18051268]),
#  array([0.49273981]),
#  array([0.07201631]),
#  array([0.0883541]),
#  array([0.19001503]),
#  array([0.16072644]),
#  array([0.7214077]),
#  array([0.03892282]),
#  array([0.21292377]),
#  array([0.43225274]),
#  array([0.4639576]),
#  array([0.01437601]),
#  array([0.42894911]),
#  array([0.27530501]),
#  array([0.39697568]),
#  array([0.35825263]),
#  array([0.46434562]),
#  array([0.0686455]),
#  array([0.83487966]),
#  array([0.69130913]),
#  array([0.00307178]),
#  array([0.21214121]),
#  array([0.8819244]),
#  array([0.04641253]),
#  array([0.02804222]),
#  array([0.91496956]),
#  array([0.2549983]),
#  array([0.42602188]),
#  array([0.26639257]),
#  array([0.59766907]),
#  array([0.03103401]),
#  array([0.4386574]),
#  array([0.19092852]),
#  array([0.06596871]),
#  array([0.26705898]),
#  array([0.82096889]),
#  array([0.08558072]),
#  array([0.1116442]),
#  array([0.07416149]),
#  array([0.16404557]),
#  array([8.99593418e-05]),
#  array([0.61872401]),
#  array([0.571882]),
#  array([0.00547008]),
#  array([0.62032772]),
#  array([0.62364693]),
#  array([0.6918578]),
#  array([0.94257081]),
#  array([0.2370778]),
#  array([0.58218813]),
#  array([0.09896773]),
#  array([0.64662901]),
#  array([0.26739593]),
#  array([0.8887646]),
#  array([0.56782563]),
#  array([0.30270835]),
#  array([0.32140244]),
#  array([0.02806677]),
#  array([0.14439557]),
#  array([0.00309752]),
#  array([0.00123566]),
#  array([0.39807072]),
#  array([0.00614517]),
#  array([0.11411995]),
#  array([0.10343274]),
#  array([0.36906889]),
#  array([0.23973305]),
#  array([0.72591577]),
#  array([0.39410989]),
#  array([0.57449237]),
#  array([0.83139323]),
#  array([0.30605127]),
#  array([0.6119958]),
#  array([0.93447568]),
#  array([0.34381593]),
#  ...]

# %% [markdown]
# Howoever, if we use the generator:

# %%
def square_numbers(nums):
    for i in nums:
        yield i**2

# %%
time3 = time.clock()
result_nums_generator = square_numbers(a)
time4 = time.clock()
print('Total time cost: ', time4-time3)
# Out:
# Total time cost:  5.845340814403244e-05

# %%
result_nums_generator
# Out:
# <generator object square_numbers at 0x000001DE2933ADB0>

# %%
print(next(result_nums_generator))
print(next(result_nums_generator))
# Out:
# [0.18142827]
# [0.09653164]
